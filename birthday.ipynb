# %%
name1,date1,month1="NIDHI",8,"MARCH"
name2,date2,month2="ROHIT",7,"NOVEMBER"
name3,date3,month3="RIDHI",15,"DECEMBER"
name4,date4,month4="VIDHISHA",27,"DECEMBER"
name5,date5,month5="INDERJEET",6,"JULY"
print(f"1. {name1}'s birthday is {month1} {date1}")
print(f"2. {name2}'s birthday is {month2} {date2}")
print(f"3. {name3}'s birthday is {month3} {date3}")
print(f"4. {name4}'s birthday is {month4} {date4}")
print(f"5. {name5}'s birthday is {month5} {date5}")
# Out:
# 1. NIDHI's birthday is MARCH 8
# 2. ROHIT's birthday is NOVEMBER 7
# 3. RIDHI's birthday is DECEMBER 15
# 4. VIDHISHA's birthday is DECEMBER 27
# 5. INDERJEET's birthday is JULY 6
