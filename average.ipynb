# %%
tree1=int(input("ENTER THE TREES HEIGHT."))
tree2=int(input("ENTER THE TREES HEIGHT."))
tree3=int(input("ENTER THE TREES HEIGHT."))
tree4=int(input("ENTER THE TREES HEIGHT."))
tree5=int(input("ENTER THE TREES HEIGHT."))
sum=tree1+tree2+tree3+tree4+tree5
print("The sum of all of the trees height is :",sum)
average=sum/5
print("The average of all of the trees height is :",average)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv (3.14.2) (Python 3.14.2)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
